# %% [markdown]
# <a href="https://colab.research.google.com/github/awildsheepchase/OpenCV/blob/main/homework2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import IPython.display as dp
from google.colab.patches import cv2_imshow

m1 = cv2.imread("h2.png",1)
m6 = cv2.divide(m1,(255,255,255,0))
m7 = cv2.multiply(m1,(255,255,255,0))
m8 = m7[100:550,50:910,1]
cv2_imshow(m8)
# Out:
# <PIL.Image.Image image mode=L size=860x450 at 0x7F8CAB9B44D0>
